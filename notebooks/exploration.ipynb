# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/data.csv")

# %%
df.head()
# Out:
#        Timestamp                 Date   Symbol      Open      High       Low  \
# 0  1676939580000  2023-02-21 00:33:00  BTC/USD  24859.34  24859.34  24859.34
# 1  1676939520000  2023-02-21 00:32:00  BTC/USD  24821.96  24859.34  24821.96
# 2  1676939460000  2023-02-21 00:31:00  BTC/USD  24818.09  24821.96  24815.47
# 3  1676939400000  2023-02-21 00:30:00  BTC/USD  24812.25  24818.09  24812.25
# 4  1676939340000  2023-02-21 00:29:00  BTC/USD  24809.27  24812.25  24809.27
#
#       Close  Volume BTC   Volume USD
# 0  24859.34    0.000000     0.000000
# 1  24859.34    0.103099  2562.977818
# 2  24821.96    0.090640  2249.866178
# 3  24818.09    0.002203    54.681450
# 4  24812.25    0.090675  2249.862431

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3766763 entries, 0 to 3766762
# Data columns (total 9 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   Timestamp   int64
#  1   Date        object
#  2   Symbol      object
#  3   Open        float64
#  4   High        float64
#  5   Low         float64
#  6   Close       float64
#  7   Volume BTC  float64
#  8   Volume USD  float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 258.6+ MB

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3766763 entries, 0 to 3766762
# Data columns (total 9 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   Timestamp   int64
#  1   Date        datetime64[ns]
#  2   Symbol      object
#  3   Open        float64
#  4   High        float64
#  5   Low         float64
#  6   Close       float64
#  7   Volume BTC  float64
#  8   Volume USD  float64
# dtypes: datetime64[ns](1), float64(6), int64(1), object(1)
# memory usage: 258.6+ MB

# %%
df.set_index('Date', inplace=True)
df.sort_index(inplace=True)

# %%
df.drop(['Symbol', 'Timestamp'], axis=1, inplace=True)
df
# Out:
#                          Open      High       Low     Close  Volume BTC  \
# Date
# 2015-10-08 13:40:00      0.00    242.50      0.00    242.50    0.050000
# 2015-10-08 13:41:00    242.50    242.95    242.50    242.95    0.001000
# 2015-10-08 13:42:00    242.95    242.95    242.95    242.95    0.000000
# 2015-10-08 13:43:00    242.95    242.96    242.95    242.96    0.010000
# 2015-10-08 13:44:00    242.96    242.96    242.96    242.96    0.033491
# ...                       ...       ...       ...       ...         ...
# 2023-02-21 00:29:00  24809.27  24812.25  24809.27  24812.25    0.090675
# 2023-02-21 00:30:00  24812.25  24818.09  24812.25  24818.09    0.002203
# 2023-02-21 00:31:00  24818.09  24821.96  24815.47  24821.96    0.090640
# 2023-02-21 00:32:00  24821.96  24859.34  24821.96  24859.34    0.103099
# 2023-02-21 00:33:00  24859.34  24859.34  24859.34  24859.34    0.000000
#
#                       Volume USD
# Date
# 2015-10-08 13:40:00    12.125000
# ...

# %%
df['SMA_30'] = df['Close'].rolling(window=30).mean()
df['SMA_100'] = df['Close'].rolling(window=100).mean()

# %%
df.tail(100)
# Out:
#                          Open      High       Low     Close  Volume BTC  \
# Date
# 2023-02-20 22:54:00  24750.14  24750.14  24748.87  24748.87    0.097488
# 2023-02-20 22:55:00  24748.87  24748.87  24721.39  24722.10    0.785044
# 2023-02-20 22:56:00  24722.10  24730.67  24714.47  24730.35    0.083787
# 2023-02-20 22:57:00  24730.35  24730.35  24715.82  24729.23    0.011925
# 2023-02-20 22:58:00  24729.23  24729.23  24715.16  24715.40    0.003281
df['BuyHold_Equity'] = (1 + df['Returns']).cumprod()

# %%
plt.figure(figsize=(12, 6))
df['Strategy_Equity'].plot(label='Strategy')
df['BuyHold_Equity'].plot(label='Buy & Hold')
plt.title('Strategy vs. Buy & Hold Equity Curves')
plt.ylabel('Equity')
plt.xlabel('Date')
plt.legend()
plt.grid(True)
plt.show()

# %%
df[['Returns', 'Signal', 'Strategy_Returns', 'Strategy_Equity', 'BuyHold_Equity']].tail(10)
# Out:
#                           Returns  Signal  Strategy_Returns  Strategy_Equity  \
# Date
# 2023-02-21 00:24:00  1.656109e-04      -1          0.000000         0.496504
# 2023-02-21 00:25:00 -4.846642e-04       0          0.000485         0.496745
# 2023-02-21 00:26:00  0.000000e+00       0          0.000000         0.496745
# 2023-02-21 00:27:00  0.000000e+00       0          0.000000         0.496745
# 2023-02-21 00:28:00 -4.030750e-07       0         -0.000000         0.496745
# 2023-02-21 00:29:00  1.201164e-04       0          0.000000         0.496745
# 2023-02-21 00:30:00  2.353676e-04      -1          0.000000         0.496745
# 2023-02-21 00:31:00  1.559346e-04      -1         -0.000156         0.496667
# 2023-02-21 00:32:00  1.505925e-03      -1         -0.001506         0.495919
# 2023-02-21 00:33:00  0.000000e+00      -1         -0.000000         0.495919
#
#                      BuyHold_Equity
# Date
# 2023-02-21 00:24:00      102.355918
# ...

# %%
subset = df.loc['2017-06-01':'2022-01-01']
plt.figure(figsize=(12, 6))
subset['Strategy_Equity'].plot(label='Strategy')
subset['BuyHold_Equity'].plot(label='Buy & Hold')
plt.title('Strategy vs. Buy & Hold Equity Curves')
plt.ylabel('Equity')
plt.xlabel('Date')
plt.legend()
plt.grid(True)
plt.show()

# %%
daily_df = df.resample('1D').agg({
    'Open': 'first',
    'High': 'max',
    'Low': 'min',
    'Close': 'last',
    'Volume BTC': 'sum', 
    'Volume USD': 'sum'
}).dropna()

daily_df.head()
# Out:
#               Open    High     Low   Close  Volume BTC    Volume USD
# Date
# 2015-10-08    0.00  245.00    0.00  243.95   31.754703   7760.410291
# 2015-10-09  243.95  249.97  243.60  245.39   56.027841  13880.647404
# 2015-10-10  245.39  246.30  244.60  246.30   39.348777   9651.169453
# 2015-10-11  246.30  249.50  245.96  249.50   14.487783   3581.307675
# 2015-10-12  249.50  249.50  247.60  247.60   62.787480  15563.142766

# %%
daily_df['Returns'] = daily_df['Close'].pct_change()

# %%
daily_df['SMA_30'] = daily_df['Close'].rolling(30).mean()
daily_df['SMA_100'] = daily_df['Close'].rolling(100).mean()

daily_df['Signal'] = 0
daily_df.loc[daily_df['Close'] < daily_df['SMA_100'], 'Signal'] = 1
daily_df.loc[daily_df['Close'] > daily_df['SMA_30'], 'Signal'] = -1

# %%
daily_df['Strategy_Returns'] = daily_df['Returns'] * daily_df['Signal'].shift(1)

# %%
daily_df['Strategy_Equity'] = (1 + daily_df['Strategy_Returns']).cumprod()
daily_df['BuyHold_Equity'] = (1 + daily_df['Returns']).cumprod()

plt.figure(figsize=(12, 6))
daily_df['Strategy_Equity'].plot(label='Strategy')
daily_df['BuyHold_Equity'].plot(label='Buy & Hold')
plt.title('Daily SMA Strategy vs Buy & Hold')
plt.legend()
plt.grid(True)
plt.show()

# %%
daily_df[['Returns', 'Signal', 'Strategy_Returns', 'Strategy_Equity', 'BuyHold_Equity']].tail(10)
# Out:
#              Returns  Signal  Strategy_Returns  Strategy_Equity  \
# Date
# 2023-02-12 -0.003454       0         -0.000000         0.000411
# 2023-02-13  0.000173       0          0.000000         0.000411
# 2023-02-14  0.019533       0          0.000000         0.000411
# 2023-02-15  0.095164      -1          0.000000         0.000411
# 2023-02-16 -0.033171      -1          0.033171         0.000425
# 2023-02-17  0.045187      -1         -0.045187         0.000406
# 2023-02-18  0.002016      -1         -0.002016         0.000405
# 2023-02-19 -0.013949      -1          0.013949         0.000411
# 2023-02-20  0.022564      -1         -0.022564         0.000401
# 2023-02-21  0.000875      -1         -0.000875         0.000401
#
#             BuyHold_Equity
# Date
# 2023-02-12       89.298627
# 2023-02-13       89.314081
# 2023-02-14       91.058660
# 2023-02-15       99.724165
# 2023-02-16       96.416192
# 2023-02-17      100.772945
# 2023-02-18      100.976143
# ...

# %%
daily_df['Signal'] = np.where(daily_df['SMA_30'] > daily_df['SMA_100'], 1, -1)

# %%
diff = (daily_df['SMA_30'] - daily_df['SMA_100']) / daily_df['SMA_100']
daily_df['Signal'] = np.where(diff > 0.01, 1, np.where(diff < -0.01, -1, 0))

# %%
daily_df['Strategy_Returns'] = daily_df['Returns'].shift(-1) * daily_df['Signal']

# %%
daily_df['Strategy_Equity'] = (1 + daily_df['Strategy_Returns']).cumprod()
daily_df['BuyHold_Equity'] = (1 + daily_df['Returns']).cumprod()

plt.figure(figsize=(12, 6))
daily_df['Strategy_Equity'].plot(label='Strategy')
daily_df['BuyHold_Equity'].plot(label='Buy & Hold')
plt.title('Daily SMA(trend following) Strategy vs Buy & Hold')
plt.legend()
plt.grid(True)
plt.show()

# %%
daily_df[['Returns', 'Signal', 'Strategy_Returns', 'Strategy_Equity', 'BuyHold_Equity']].tail(10)
# Out:
#              Returns  Signal  Strategy_Returns  Strategy_Equity  \
# Date
# 2023-02-12 -0.003454       1          0.000173        25.359074
# 2023-02-13  0.000173       1          0.019533        25.854415
# 2023-02-14  0.019533       1          0.095164        28.314824
# 2023-02-15  0.095164       1         -0.033171        27.375587
# 2023-02-16 -0.033171       1          0.045187        28.612606
# 2023-02-17  0.045187       1          0.002016        28.670300
# 2023-02-18  0.002016       1         -0.013949        28.270387
# 2023-02-19 -0.013949       1          0.022564        28.908281
# 2023-02-20  0.022564       1          0.000875        28.933584
# 2023-02-21  0.000875       1               NaN              NaN
#
#             BuyHold_Equity
# Date
# 2023-02-12       89.298627
# 2023-02-13       89.314081
# 2023-02-14       91.058660
# 2023-02-15       99.724165
# 2023-02-16       96.416192
# 2023-02-17      100.772945
# 2023-02-18      100.976143
# ...
